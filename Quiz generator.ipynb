# %%
import re

# Read the contents of the TXT file
with open('[English] Cybersecurity IDR_ Incident Detection & Response _ Google Cybersecurity Certificate [DownSub.com].txt', 'r') as file:
    text = file.read()
    
# Replace line breaks and paragraphs with spaces
text = re.sub(r'[\n\r]+', ' ', text)

# Save the cleaned text to a new file or use it for further analysis
with open('cleaned_text.txt', 'w') as file:
    file.write(text)

# %%
from transformers import pipeline

# %%
model = pipeline("text-generation", model="Cybernetyx/TARS_v0.2_QZ_ZS_1K")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File ~/.pyenv/versions/3.10.6/envs/JC/lib/python3.10/site-packages/urllib3/connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File ~/.pyenv/versions/3.10.6/envs/JC/lib/python3.10/site-packages/urllib3/util/connection.py:95, in create_connection(address, timeout, source_address, socket_options)
#      94 if err is not None:
# ---> 95     raise err
#      97 raise socket.error("getaddrinfo returns an empty list")
#
# File ~/.pyenv/versions/3.10.6/envs/JC/lib/python3.10/site-packages/urllib3/util/connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84     sock.bind(source_address)
# ...

# %%
from transformers import undefined

model = undefined.from_pretrained("undefined")
model.load_adapter("Cybernetyx/TARS_v0.2_QZ_ZS_1K", source="hf")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In [34], line 1
# ----> 1 from transformers import undefined
#       3 model = undefined.from_pretrained("undefined")
#       4 model.load_adapter("Cybernetyx/TARS_v0.2_QZ_ZS_1K", source="hf")
#
# ImportError: cannot import name 'undefined' from 'transformers' (/home/jessica/.pyenv/versions/3.10.6/envs/JC/lib/python3.10/site-packages/transformers/__init__.py)

# %%
prompt = "In which year was the French Revolution?"
generated_questions = model(prompt, num_return_sequences=5)
for question in generated_questions:
    print(question['generated_text'])
